# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.mode.chained_assignment = None  # default='warn'
# %matplotlib inline

# %%
##Women and children first?
##1. Describe each attribute, both with basic statistics and plots. State clearly your assumptions and discuss your findings.
##2. Use the `groupby` method to calculate the proportion of passengers that survived by sex.
##3. Calculate the same proportion, but by class and sex.
##4. Create age categories: children (under 14 years), adolescents (14-20), adult (21-64), and senior(65+), and calculate survival proportions by age category, class and sex.

# %% [markdown]
# ##### Loading the data from excel file using pandas .read_excel

# %%
titanic=pd.read_excel('Data/titanic.xls')

# %%
#quick way to look at how many rows and columns
titanic.shape
# Out:
# (1309, 14)

# %% [markdown]
# ######  from the output above we notice that the data has 1309 rows (observation) and 14 columns(attribute)

# %%
#looking at the the names and the type of the attributes 
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# ###### from the output above we see that some attributes with type of int and others with float and object.

# %%
#quick look at the first rows to make sure that everything is aloright.
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ###### 1.Describe each attribute, both with basic statistics and plots. State clearly your assumptions and discuss your findings.
# Solution:

# %% [markdown]
# ##### First, we want to have a quick look at the summery of the numarical values

# %%
#summry of the data
titanic.describe()
# Out:
# /Users/Ray/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000          NaN     0.000000     0.000000
# 50%       3.000000     0.000000          NaN     0.000000     0.000000
# 75%       3.000000     1.000000          NaN     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%            NaN         NaN
# 50%            NaN         NaN
# 75%            NaN         NaN
# max     512.329200  328.000000

# %% [markdown]
# ###### From the initial resutls we got above, we can see for each numerical attribute some basic statistics such as count, mean, std, max and so on we clearly see there are some missing values from the age, fare, and body columns. we will deal with them later in this notebook!

# %% [markdown]
# ##### And also we can have a quick look at the summery of the categorical values as well

# %%
categorical = titanic.dtypes[titanic.dtypes == "object"].index
print(categorical)

titanic[categorical].describe()
# Out:
# Index(['name', 'sex', 'ticket', 'cabin', 'embarked', 'boat', 'home.dest'], dtype='object')
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1307  486
# unique                  1307     2       939          186        3   28
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      914   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %% [markdown]
# ###### From the resutls above, we notice that there might be some duplicates in the data since we got 1307 unique names out of the 1309 or it might be that some passengers have the same name, we will see!

# %%
#name attribute
#quick way to see how do the names look like
sorted(titanic["name"].head(10))
# Out:
# ['Allen, Miss. Elisabeth Walton',
#  'Allison, Master. Hudson Trevor',
#  'Allison, Miss. Helen Loraine',
#  'Allison, Mr. Hudson Joshua Creighton',
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#  'Anderson, Mr. Harry',
#  'Andrews, Miss. Kornelia Theodosia',
#  'Andrews, Mr. Thomas Jr',
#  'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#  'Artagaveytia, Mr. Ramon']

# %%
titanic["name"].describe()
# Out:
# count                     1309
# unique                    1307
# top       Connolly, Miss. Kate
# freq                         2
# Name: name, dtype: object

# %% [markdown]
# ###### Now we want to verify if we have a duplicates or people having similar names!
# ###### So, let's find those rows with the same values in the name column

# %%
#here we try to find the rows with the same value in the name column
#create a list of the exact names that appears more than once
common_names=titanic.set_index('name').index.get_duplicates()

# %%
#have a quick look to those rows 
titanic.loc[titanic['name'].isin(common_names)]
# Out:
#      pclass  survived                  name     sex   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female  22.0      0      0
# 726       3         0  Connolly, Miss. Kate  female  30.0      0      0
# 924       3         0      Kelly, Mr. James    male  34.5      0      0
# 925       3         0      Kelly, Mr. James    male  44.0      0      0
#
#      ticket    fare cabin embarked boat  body home.dest
# 725  370373  7.7500   NaN        Q   13   NaN   Ireland
# 726  330972  7.6292   NaN        Q  NaN   NaN   Ireland
# 924  330911  7.8292   NaN        Q  NaN  70.0       NaN
# 925  363592  8.0500   NaN        S  NaN   NaN       NaN

# %% [markdown]
# from the results above, we can confirm that we have no duplicates on the dataset based on name, the reseon is that those people share similar names but with different ages, this is the case for (Connolly, Miss. Kate and Kelly, Mr. James)  and aslo two persons with the exact same name (Connolly, Miss. Kate) one of them survived and the other didn't.
#
# So this confirms the assumption that we have different passengers with the same exact name.

# %%
#age attribute, lets have a look
titanic["age"].describe()
# Out:
# /Users/Ray/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max        80.000000
# Name: age, dtype: float64

# %% [markdown]
# *Above basic results show that there are some missing values!!
#
# let's find out what rows has a missing age value..

# %%
titanic[titanic["age"].isnull()]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 69         1         1             Chibnall, Mrs. (Edith Martha Bowerman)
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 74         1         0                        Clifford, Mr. George Quincy
# 80         1         0                          Crafton, Mr. John Bertram
# 106        1         0                                 Farthing, Mr. John
# 107        1         1               Flegenheim, Mrs. Alfred (Antoinette)
# 108        1         1                            Fleming, Miss. Margaret
# 118        1         0                        Franklin, Mr. Thomas Parham
# 121        1         1  Frauenthal, Mrs. Henry William (Clara Heinshei...
# 125        1         0                                   Fry, Mr. Richard
# 134        1         1       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 147        1         0                          Harrington, Mr. Charles H
# 152        1         1                        Hawksford, Mr. Walter James
# 157        1         0                        Hilliard, Mr. Herbert Henry
# 166        1         0                           Hoyt, Mr. William Fisher
# 176        1         1                  Kenyon, Mrs. Frederick R (Marion)
# 179        1         0                                 Klaber, Mr. Herman
# 184        1         0                                  Lewy, Mr. Ervin G
# 196        1         1                               Marechal, Mr. Pierre
# 204        1         1              Meyer, Mrs. Edgar Joseph (Leila Saks)
# 219        1         1                          Omont, Mr. Alfred Fernand
# 223        1         0                      Parr, Mr. William Henry Marsh
# 235        1         1                Rheims, Mr. George Alexander Lucien
# 237        1         0                                Robbins, Mr. Victor
# 241        1         0                              Rood, Mr. Hugh Roscoe
# 1212  NaN   NaN                               NaN
# 1213  NaN   NaN                               NaN
# 1214  NaN   NaN                               NaN
# 1215  NaN   NaN                               NaN
# 1216   13   NaN                               NaN
# 1219  NaN   NaN                               NaN
# 1221  NaN   NaN                               NaN
# 1241  NaN   NaN                               NaN
# 1242  NaN   NaN                               NaN
# 1243  NaN   NaN                               NaN
# 1245  NaN   NaN                               NaN
# 1246  NaN   NaN                               NaN
# 1247   10   NaN                               NaN
# 1249  NaN   NaN                               NaN
# 1250  NaN   NaN                               NaN
# 1253  NaN   NaN                               NaN
# 1255  NaN   NaN                               NaN
# 1262  NaN   NaN                               NaN
# 1268  NaN   NaN                               NaN
# 1282  NaN   NaN                               NaN
# 1283  NaN   NaN                               NaN
# 1284  NaN   NaN                               NaN
# 1291  NaN   NaN                               NaN
# 1292  NaN   NaN                               NaN
# 1293  NaN   NaN                               NaN
# 1297  NaN   NaN                               NaN
# 1302  NaN   NaN                               NaN
# 1303  NaN   NaN                               NaN
# 1305  NaN   NaN                               NaN
#
# [263 rows x 14 columns]

# %%
#check how many observation has a missing age
titanic["age"].isnull().sum()
# Out:
# 263

# %% [markdown]
# we have 263 obsevation with missing ages, we have to find a solution for that..
#
# - one solution is that we can drop all rows with ages with NaN value! but 263 is a lot, we will probably lose some information, 263 is approximatly 20% of the whole dataset so it might not be a good idea.
#
# - or we can fill these missing values with 0s! But since it is age it doesn't make a lot of sense to fill these values with 0s.
#
# - or find the a value in the middle and use it to fill in these missing values.
#
# - or try to predict the missing ages using a machine learning algorithm..
#
# Let's see the age distribution first!

# %%
titanic.hist(column='age', figsize=(17,10), bins=20, color = 'blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14a8c73c8>]], dtype=object)

# %% [markdown]
# From the histogram above, we see that ages between 20 and 30 are the most common ages, so filling in the missing values with a central number like the median is not a very bad idea.
# Let's fill in the missing values with the median.

# %%
#caluculate the median of the age attribute
titanic["age"].median()
# Out:
# 28.0

# %%
#Replacing NaN values with the median value 28..  
median_age = np.where(titanic["age"].isnull(), 28, titanic["age"])    
titanic["age"] = median_age
titanic["age"].describe()
# Out:
# count    1309.000000
# mean       29.503183
# std        12.905246
# min         0.166700
# 25%        22.000000
# 50%        28.000000
# 75%        35.000000
# max        80.000000
# Name: age, dtype: float64

# %%
# now let's see the new age distribution
titanic.hist(column='age', figsize=(17,10), bins=20, color = 'blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14a8b89b0>]], dtype=object)

# %% [markdown]
# Not very bad! for the purpose of this homework we believe that this is fine.. However, when work with a real model we can test and see the effect of such a decision and then adjuct accordingly!

# %%
#fare attribute
titanic["fare"].describe()
# Out:
# /Users/Ray/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max       512.329200
# Name: fare, dtype: float64

# %% [markdown]
# *Above basic results show that there are some missing values!!
#
# let's find out what rows has a missing fare value..

# %%
#check how many observation has a missing fare
titanic["fare"].isnull().sum()
# Out:
# 1

# %%
#let's find out which row
titanic[titanic.fare.isnull()]
# Out:
#       pclass  survived                name   sex   age  sibsp  parch ticket  \
# 1225       3         0  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#       fare cabin embarked boat   body home.dest
# 1225   NaN   NaN        S  NaN  261.0       NaN

# %% [markdown]
# This is the only passenger with missing fare value, and interstingly by looking at https://www.encyclopedia-titanica.org/titanic-victim/thomas-storey.html we find that his job was a Seaman so it makes sence to assume that this guy has 0 fare and based on this assumption we will fill the missing fare value with zaro.

# %%
new_fare = np.where(titanic["fare"].isnull(), 0, titanic["fare"])    
titanic["fare"] = new_fare
titanic["fare"].describe()
# Out:
# count    1309.000000
# mean       33.270043
# std        51.747063
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: fare, dtype: float64

# %% [markdown]
# Another thing that we noticed from the basic statistics above is that there are some people with values of zaro in the fare attribute.

# %%
titanic[titanic['fare']==0].shape
# Out:
# (18, 14)

# %%
titanic[titanic['fare']==0]
# Out:
#       pclass  survived                                   name   sex   age  \
# 7          1         0                 Andrews, Mr. Thomas Jr  male  39.0
# 70         1         0  Chisholm, Mr. Roderick Robert Crispin  male  28.0
# 125        1         0                       Fry, Mr. Richard  male  28.0
# 150        1         0                  Harrison, Mr. William  male  40.0
# 170        1         1                Ismay, Mr. Joseph Bruce  male  49.0
# 223        1         0          Parr, Mr. William Henry Marsh  male  28.0
# 234        1         0        Reuchlin, Jonkheer. John George  male  38.0
# 363        2         0                  Campbell, Mr. William  male  28.0
# 384        2         0         Cunningham, Mr. Alfred Fleming  male  28.0
# 410        2         0       Frost, Mr. Anthony Wood "Archie"  male  28.0
# 473        2         0                   Knight, Mr. Robert J  male  28.0
# 528        2         0            Parkes, Mr. Francis "Frank"  male  28.0
# 581        2         0             Watson, Mr. Ennis Hastings  male  28.0
# 896        3         0                    Johnson, Mr. Alfred  male  49.0
# 898        3         0        Johnson, Mr. William Cahoone Jr  male  19.0
# 963        3         0                    Leonard, Mr. Lionel  male  36.0
# 1225       3         0                     Storey, Mr. Thomas  male  60.5
# 1254       3         1           Tornquist, Mr. William Henry  male  25.0
#
#       sibsp  parch  ticket  fare        cabin embarked boat   body  \
# 7         0      0  112050   0.0          A36        S  NaN    NaN
# 70        0      0  112051   0.0          NaN        S  NaN    NaN
# 125       0      0  112058   0.0         B102        S  NaN    NaN
# 150       0      0  112059   0.0          B94        S  NaN  110.0
# 170       0      0  112058   0.0  B52 B54 B56        S    C    NaN
# 223       0      0  112052   0.0          NaN        S  NaN    NaN
# 234       0      0   19972   0.0          NaN        S  NaN    NaN
# 363       0      0  239853   0.0          NaN        S  NaN    NaN
# 384       0      0  239853   0.0          NaN        S  NaN    NaN
# 410       0      0  239854   0.0          NaN        S  NaN    NaN
# 473       0      0  239855   0.0          NaN        S  NaN    NaN
# 528       0      0  239853   0.0          NaN        S  NaN    NaN
# 581       0      0  239856   0.0          NaN        S  NaN    NaN
# 896       0      0    LINE   0.0          NaN        S  NaN    NaN
# 898       0      0    LINE   0.0          NaN        S  NaN    NaN
# 963       0      0    LINE   0.0          NaN        S  NaN    NaN
# 1225      0      0    3701   0.0          NaN        S  NaN  261.0
# 1254      0      0    LINE   0.0          NaN        S   15    NaN
#
#                          home.dest
# 7                      Belfast, NI
# 70    Liverpool, England / Belfast
# 125                            NaN
# 150                            NaN
# 170                      Liverpool
# 223                        Belfast
# 234         Rotterdam, Netherlands
# 363                        Belfast
# 384                        Belfast
# 410                        Belfast
# 473                        Belfast
# 528                        Belfast
# 581                        Belfast
# 896                            NaN
# 898                            NaN
# 963                            NaN
# 1225                           NaN
# 1254                           NaN

# %% [markdown]
# By looking at some of them online, intrestingly we found that some of them were seamen and others Fitter workin on the ship. and others like "Reuchlin, Jonkheer. John George" and intrestingly, by looking at https://www.encyclopedia-titanica.org/titanic-victim/johan-george-reuchlin.html we find that "John George" was holding a complementary tickets because of his position with the Holland America Line so it explains why there is a zero in the vlaue of the fare attribute.
# so it makes since that the fare is 0.

# %%
#looking at the fare distribution
titanic.hist(column='fare', figsize=(17,10), bins= 20, color = 'blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14b258e48>]], dtype=object)

# %% [markdown]
# we can clearly see that, the majority of the passengers paid an amount between 0-50.. and also we found that there were some outliers who paid way more then that..
#
# We use boxplot to have a better look at thoso outliers..

# %%
#boxplot - fare..
sns.set_style("whitegrid")
sns.boxplot(titanic.fare, color = 'blue')

# %%
#boxplot without outliers..
sns.boxplot(titanic.fare, showfliers=False, color = 'blue')

# %%
#show the passenger who paid more than
titanic[titanic['fare']>300]
# Out:
#      pclass  survived                                               name  \
# 49        1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 183       1         1                             Lesurer, Mr. Gustave J
# 302       1         1                                   Ward, Miss. Anna
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 49     male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 50   female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 183    male  35.0      0      0  PC 17755  512.3292         B101        C
# 302  female  35.0      0      0  PC 17755  512.3292          NaN        C
#
#     boat  body                                       home.dest
# 49     3   NaN  Austria-Hungary / Germantown, Philadelphia, PA
# 50     3   NaN                    Germantown, Philadelphia, PA
# 183    3   NaN                                             NaN
# 302    3   NaN                                             NaN

# %% [markdown]
# looking at "Mr Thomas Drake Martinez Cardeza" online, we found that he and his mother They occupied one of the two most luxurious suites on board..
# https://www.encyclopedia-titanica.org/titanic-survivor/thomas-cardeza.html

# %%
#survived attribute 
titanic.survived.value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
#making sure no missing data 
titanic[titanic.survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
#plot survived
titanic.survived.value_counts().plot(kind='bar',color = 'blue',figsize=(9,5))

# %%
#persentage of people that have survived and who have not..
titanic.survived.value_counts()/titanic.survived.count()*100
# Out:
# 0    61.802903
# 1    38.197097
# Name: survived, dtype: float64

# %% [markdown]
# ~62% died and ~ 38% survived

# %%
#sex attribute 
titanic.sex.value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
#making sure no missing data 
titanic[titanic.sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
titanic.sex.value_counts().plot(kind='bar',color = 'blue',figsize=(9,5))

# %%
#persentage of females and males..
titanic.sex.value_counts()/titanic.sex.count()*100
# Out:
# male      64.400306
# female    35.599694
# Name: sex, dtype: float64

# %% [markdown]
# ~64% males and ~36% females

# %%
#pclass attribute 
titanic.pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
#making sure no missing data 
titanic[titanic.pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
titanic.pclass.value_counts().plot(kind='bar', color = 'blue',figsize=(9,5))

# %%
#persentage of each class..
titanic.pclass.value_counts()/titanic.pclass.count()*100
# Out:
# 3    54.163484
# 1    24.675325
# 2    21.161192
# Name: pclass, dtype: float64

# %% [markdown]
# class1 -> ~25% .. class2 -> 21% .. class3 -> 54%

# %%
#home.dest attribute

# %%
titanic['home.dest'].describe()
# Out:
# count              745
# unique             369
# top       New York, NY
# freq                64
# Name: home.dest, dtype: object

# %%
#check missing data 
titanic[titanic['home.dest'].isnull()]
# Out:
#       pclass  survived                                             name  \
# 13         1         1                     Barber, Miss. Ellen "Nellie"
# 18         1         1                            Bazzani, Miss. Albina
# 23         1         1                            Bidois, Miss. Rosalie
# 24         1         1                                Bird, Miss. Ellen
# 28         1         1                           Bissette, Miss. Amelia
# 44         1         1                  Burns, Miss. Elizabeth Margaret
# 46         1         0                            Cairns, Mr. Alexander
# 66         1         1                      Chaudanson, Miss. Victorine
# 73         1         1                             Cleaver, Miss. Alice
# 88         1         1                             Daniels, Miss. Sarah
# 106        1         0                               Farthing, Mr. John
# 108        1         1                          Fleming, Miss. Margaret
# 117        1         1                   Francatelli, Miss. Laura Mabel
# 125        1         0                                 Fry, Mr. Richard
# 129        1         1                             Geiger, Miss. Amalie
# 132        1         0                               Giglio, Mr. Victor
# 147        1         0                        Harrington, Mr. Charles H
# 150        1         0                            Harrison, Mr. William
# 151        1         1                               Hassab, Mr. Hammad
# 168        1         1                              Icard, Miss. Amelie
# 173        1         0                               Keeping, Mr. Edwin
# 180        1         1                           Kreuchen, Miss. Emilie
# 182        1         1                              LeRoy, Miss. Bertha
# 183        1         1                           Lesurer, Mr. Gustave J
# 192        1         1                             Lurette, Miss. Elise
# 195        1         1                            Maioni, Miss. Roberta
# 218        1         1                     Oliva y Ocana, Dona. Fermina
# 230        1         1                            Perreault, Miss. Anne
# 236        1         0                              Ringhini, Mr. Sante
# 237        1         0                              Robbins, Mr. Victor
# ...      ...       ...                                              ...
# 1278       3         0                           Vendel, Mr. Olof Edvin
# 1279       3         0             Vestrom, Miss. Hulda Amanda Adolfina
# 1280       3         0                                  Vovk, Mr. Janko
# 1282       3         0                              Ware, Mr. Frederick
# 1283       3         0                      Warren, Mr. Charles William
# 1284       3         0                                Webber, Mr. James
# 1285       3         0                              Wenzel, Mr. Linhart
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1288       3         0                        Wiklund, Mr. Jakob Alfred
# 1289       3         0                          Wiklund, Mr. Karl Johan
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1291       3         0                 Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                               Willey, Mr. Edward
# 1293       3         0                Williams, Mr. Howard Hugh "Harry"
# 1294       3         0
# 1292    male  28.0      0      0     S.O./P.P. 751    7.5500   NaN        S
# 1293    male  28.0      0      0          A/5 2466    8.0500   NaN        S
# 1294    male  28.5      0      0             54636   16.1000   NaN        S
# 1295    male  21.0      0      0  SOTON/OQ 3101317    7.2500   NaN        S
# 1296    male  27.0      0      0            315154    8.6625   NaN        S
# 1297    male  28.0      0      0        A/4. 34244    7.2500   NaN        S
# 1298    male  36.0      0      0            345771    9.5000   NaN        S
# 1299    male  27.0      1      0              2659   14.4542   NaN        C
# 1300  female  15.0      1      0              2659   14.4542   NaN        C
# 1301    male  45.5      0      0              2628    7.2250   NaN        C
# 1302    male  28.0      0      0              2647    7.2250   NaN        C
# 1303    male  28.0      0      0              2627   14.4583   NaN        C
# 1304  female  14.5      1      0              2665   14.4542   NaN        C
# 1305  female  28.0      1      0              2665   14.4542   NaN        C
# 1306    male  26.5      0      0              2656    7.2250   NaN        C
# 1307    male  27.0      0      0              2670    7.2250   NaN        C
# 1308    male  29.0      0      0            315082    7.8750   NaN        S
#
#      boat   body home.dest
# 13      6    NaN       NaN
# 18      8    NaN       NaN
# 23      4    NaN       NaN
# 24      8    NaN       NaN
# 28      8    NaN       NaN
# 44      3    NaN       NaN
# 46    NaN    NaN       NaN
# 66      4    NaN       NaN
# 73     11    NaN       NaN
# 88      8    NaN       NaN
# 106   NaN    NaN       NaN
# 108     4    NaN       NaN
# 117     1    NaN       NaN
# 125   NaN    NaN       NaN
# 129     4    NaN       NaN
# 132   NaN    NaN       NaN
# 147   NaN    NaN       NaN
# 150   NaN  110.0       NaN
# 151     3    NaN       NaN
# 168     6    NaN       NaN
# 173   NaN   45.0       NaN
# 180     2    NaN       NaN
# 182     2    NaN       NaN
# 183     3    NaN       NaN
# 192   NaN    NaN       NaN
# 195     8    NaN       NaN
# 218     8    NaN       NaN
# 230     3    NaN       NaN
# 236   NaN  232.0       NaN
# 237   NaN    NaN       NaN
# ...   ...    ...       ...
# 1278  NaN    NaN       NaN
# 1279  NaN    NaN       NaN
# 1280  NaN    NaN       NaN
# 1282  NaN    NaN       NaN
# 1283  NaN    NaN       NaN
# 1284  NaN    NaN       NaN
# 1285  NaN  298.0       NaN
# 1286    C    NaN       NaN
# 1287  NaN    NaN       NaN
# 1288  NaN  314.0       NaN
# 1289  NaN    NaN       NaN
# 1290  NaN    NaN       NaN
# 1291  NaN    NaN       NaN
# 1292  NaN    NaN       NaN
# 1293  NaN    NaN       NaN
# 1294  NaN   14.0       NaN
# 1295  NaN    NaN       NaN
# 1296  NaN  131.0       NaN
# 1297  NaN    NaN       NaN
# 1298  NaN    NaN       NaN
# 1299    C    NaN       NaN
# 1300  NaN    NaN       NaN
# 1301  NaN  312.0       NaN
# 1302  NaN    NaN       NaN
# 1303  NaN    NaN       NaN
# 1304  NaN  328.0       NaN
# 1305  NaN    NaN       NaN
# 1306  NaN  304.0       NaN
# 1307  NaN    NaN       NaN
# 1308  NaN    NaN       NaN
#
# [564 rows x 14 columns]

# %% [markdown]
# 564 rows with no home.dest values

# %%
#check the most common values for home.dest attribute
#assuming the format of (Home/Destination)
titanic['home.dest'].value_counts()
# Out:
# New York, NY                                      64
# London                                            14
# Montreal, PQ                                      10
# Cornwall / Akron, OH                               9
# Paris, France                                      9
# Winnipeg, MB                                       8
# Wiltshire, England Niagara Falls, NY               8
# Philadelphia, PA                                   8
# Belfast                                            7
# Sweden Winnipeg, MN                                7
# Brooklyn, NY                                       7
# Sweden Worcester, MA                               5
# Rotherfield, Sussex, England Essex Co, MA          5
# Bulgaria Chicago, IL                               5
# Haverford, PA / Cooperstown, NY                    5
# Somerset / Bernardsville, NJ                       5
# Ottawa, ON                                         5
# Paris / Montreal, PQ                               4
# Montreal, PQ / Chesterville, ON                    4
# Bournmouth, England                                4
# Minneapolis, MN                                    4
# Paris / Haiti                                      4
# Syria New York, NY                                 4
# Austria                                            4
# Washington, DC                                     4
# Ruotsinphytaa, Finland New York, NY                4
# Guntur, India / Benton Harbour, MI                 4
# Bryn Mawr, PA                                      4
# Ireland New York, NY                               4
# London, England                                    4
#                                                   ..
# Finland / Washington, DC                           1
# Harrow, England                                    1
# Tokyo, Japan                                       1
# Rotterdam, Netherlands                             1
# Cincinatti, OH                                     1
# Bath, England / Massachusetts                      1
# London Skanteales, NY                              1
# Co Sligo, Ireland New York, NY                     1
# Greensburg, PA                                     1
# Vadsbro, Sweden Ministee, MI                       1
# Bristol, England Cleveland, OH                     1
# Russia                                             1
# ?Havana, Cuba                                      1
# Austria-Hungary                                    1
# Albany, NY                                         1
# England / Philadelphia, PA                         1
# England Oglesby, IL                                1
# Belfast, NI                                        1
# Lake Arthur, Chavez County, NM                     1
# Krakudden, Sweden Moune, IL                        1
# England New York, NY                               1
# Portugal / Sau Paulo, Brazil                       1
# India / Pittsburgh, PA                             1
# Kontiolahti, Finland / Detroit, MI                 1
# Paris /  New York, NY                              1
# Denver, CO                                         1
# Jacksonville, FL                                   1
# Austria-Hungary / Germantown, Philadelphia, PA     1
# Co Cork, Ireland Roxbury, MA                       1
# Elmira, NY / Orange, NJ                            1
# Name: home.dest, dtype: int64

# %% [markdown]
# the result above shows that, the most common value for this column is "New York, NY" with 64 occurrences and the second top is "london", and so on.. its cleare that New York, NY is a destination however using only this dataset it's hard to tell about the rest.. but the result above gives some perspective..

# %%
#plot of the 10 most frequent home/dest
titanic['home.dest'].value_counts().head(10).plot(kind='bar', color = 'blue',figsize=(18,5))

# %%
#sibsp attribute 
titanic['sibsp'].describe()
# Out:
# count    1309.000000
# mean        0.498854
# std         1.041658
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         8.000000
# Name: sibsp, dtype: float64

# %%
#check missing data 

titanic[titanic.sibsp.isnull()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
titanic.sibsp.value_counts().plot(kind='bar', color = 'blue',figsize=(15,5))

# %%
titanic.sibsp.value_counts()/titanic.sibsp.count()*100
# Out:
# 0    68.067227
# 1    24.369748
# 2     3.208556
# 4     1.680672
# 3     1.527884
# 8     0.687548
# 5     0.458365
# Name: sibsp, dtype: float64

# %% [markdown]
# The result above shows that ~68% of the passengers traveled on the ship without any siblings or spouse.. and ~24% traveled on the ship with only one sibling or spouse. and only ~3% of them was on the ship with 2 siblings or spouse.
# the other persentage of the freq of sib/spouse is above.

# %%
#parch attribute 
titanic['parch'].describe()
# Out:
# count    1309.000000
# mean        0.385027
# std         0.865560
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         9.000000
# Name: parch, dtype: float64

# %%
#check missing data 
titanic[titanic.parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
titanic.parch.value_counts().plot(kind='bar', color = 'blue',figsize=(15,5))
#check whar parch is..

# %%
titanic.parch.value_counts()/titanic.parch.count()*100
# Out:
# 0    76.546982
# 1    12.987013
# 2     8.632544
# 3     0.611154
# 5     0.458365
# 4     0.458365
# 9     0.152788
# 6     0.152788
# Name: parch, dtype: float64

# %% [markdown]
# The result above shows that ~76% of the passengers traveled on the ship without any parents or children.. and ~12% traveled on the ship with only one parent or a child. and only ~8% of them was on the ship with 2 parents or children.
# the other persentage of the freq of parent/child is above.

# %%
#cabin attribute 
titanic['cabin'].describe()
# Out:
# count             295
# unique            186
# top       C23 C25 C27
# freq                6
# Name: cabin, dtype: object

# %%
#check missing values
titanic[titanic.cabin.isnull()]
# Out:
#       pclass  survived                                               name  \
# 9          1         0                            Artagaveytia, Mr. Ramon
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 15         1         0                                Baumann, Mr. John D
# 23         1         1                              Bidois, Miss. Rosalie
# 25         1         0                                Birnbaum, Mr. Jakob
# 35         1         1                           Bowen, Miss. Grace Scott
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 48         1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 52         1         0                            Carrau, Mr. Francisco M
# 53         1         0                             Carrau, Mr. Jose Pedro
# 58         1         0                             Case, Mr. Howard Brown
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 73         1         1                               Cleaver, Miss. Alice
# 80         1         0                          Crafton, Mr. John Bertram
# 87         1         1                        Daniel, Mr. Robert Williams
# 88         1         1                               Daniels, Miss. Sarah
# 107        1         1               Flegenheim, Mrs. Alfred (Antoinette)
# 108        1         1                            Fleming, Miss. Margaret
# 119        1         1                      Frauenthal, Dr. Henry William
# 121        1         1  Frauenthal, Mrs. Henry William (Clara Heinshei...
# 130        1         1                     Gibson, Miss. Dorothy Winifred
# 131        1         1            Gibson, Mrs. Leonard (Pauline C Boeson)
# 147        1         0                          Harrington, Mr. Charles H
# 162        1         0                     Holverson, Mr. Alexander Oskar
# 163        1         1  Holverson, Mrs. Alexander Oskar (Mary Aline To...
# 164        1         1                    Homer, Mr. Harry ("Mr E Haven")
# 166        1         0                           Hoyt, Mr. William Fisher
# ...      ...       ...                                                ...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1280       3         0                                    Vovk, Mr. Janko
# 1281       3         0                               Waelens, Mr. Achille
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1285       3         0                                Wenzel, Mr. Linhart
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                   Widegren, Mr. Carl/Charles Peter
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1289       3         0                            Wiklund, Mr. Karl Johan
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1294       3         0                               Williams, Mr. Leslie
# 1295       3         0                                Windelov, Mr. Einar
# 1296       3         0                                   Wirz, Mr. Albert
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1298       3         0                          Wittevrongel, Mr. Camille
# 1299       3         0                                Yasbeck, Mr. Antoni
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301       3         0                               Youseff, Mr. Gerious
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
# 1306       3         0                          Zakarian, Mr. Mapriededer
# 1307       3         0                                Zakarian, Mr. Ortin
# 1308       3         0                                 Zimmerman, Mr. Leo
#
#          s
# 1302    male  28.0      0      0              2647    7.2250   NaN        C
# 1303    male  28.0      0      0              2627   14.4583   NaN        C
# 1304  female  14.5      1      0              2665   14.4542   NaN        C
# 1305  female  28.0      1      0              2665   14.4542   NaN        C
# 1306    male  26.5      0      0              2656    7.2250   NaN        C
# 1307    male  27.0      0      0              2670    7.2250   NaN        C
# 1308    male  29.0      0      0            315082    7.8750   NaN        S
#
#      boat   body                         home.dest
# 9     NaN   22.0               Montevideo, Uruguay
# 13      6    NaN                               NaN
# 15    NaN    NaN                      New York, NY
# 23      4    NaN                               NaN
# 25    NaN  148.0                 San Francisco, CA
# 35      4    NaN                   Cooperstown, NY
# 37      9    NaN                   Los Angeles, CA
# 40    NaN    NaN                  Philadelphia, PA
# 46    NaN    NaN                               NaN
# 48      6    NaN                    Washington, DC
# 52    NaN    NaN               Montevideo, Uruguay
# 53    NaN    NaN               Montevideo, Uruguay
# 58    NaN    NaN  Ascot, Berkshire / Rochester, NY
# 59      5    NaN                      New York, NY
# 70    NaN    NaN      Liverpool, England / Belfast
# 73     11    NaN                               NaN
# 80    NaN    NaN                     Roachdale, IN
# 87      3    NaN                  Philadelphia, PA
# 88      8    NaN                               NaN
# 107     7    NaN                      New York, NY
# 108     4    NaN                               NaN
# 119     5    NaN                      New York, NY
# 121     5    NaN                      New York, NY
# 130     7    NaN                      New York, NY
# 131     7    NaN                      New York, NY
# 147   NaN    NaN                               NaN
# 162   NaN   38.0                      New York, NY
# 163     8    NaN                      New York, NY
# 164    15    NaN                  Indianapolis, IN
# 166    14    NaN                      New York, NY
# ...   ...    ...                               ...
# 1279  NaN    NaN                               NaN
# 1280  NaN    NaN                               NaN
# 1281  NaN    NaN    Antwerp, Belgium / Stanton, OH
# 1282  NaN    NaN                               NaN
# 1283  NaN    NaN                               NaN
# 1284  NaN    NaN                               NaN
# 1285  NaN  298.0                               NaN
# 1286    C    NaN                               NaN
# 1287  NaN    NaN                               NaN
# 1288  NaN  314.0                               NaN
# 1289  NaN    NaN                               NaN
# 1290  NaN    NaN                               NaN
# 1291  NaN    NaN                               NaN
# 1292  NaN    NaN                               NaN
# 1293  NaN    NaN                               NaN
# 1294  NaN   14.0                               NaN
# 1295  NaN    NaN                               NaN
# 1296  NaN  131.0                               NaN
# 1297  NaN    NaN                               NaN
# 1298  NaN    NaN                               NaN
# 1299    C    NaN                               NaN
# 1300  NaN    NaN                               NaN
# 1301  NaN  312.0                               NaN
# 1302  NaN    NaN                               NaN
# 1303  NaN    NaN                               NaN
# 1304  NaN  328.0                               NaN
# 1305  NaN    NaN                               NaN
# 1306  NaN  304.0                               NaN
# 1307  NaN    NaN                               NaN
# 1308  NaN    NaN                               NaN
#
# [1014 rows x 14 columns]

# %% [markdown]
# The result above shows that there are 1014 passenger with missing cabin code.
#
# it might be the case that most passengers did not stay in a Cabin.
#
# ???????????????????? In this case, False is a value that I have constructed from the NaNs in the original dataset. That NaN meant that a passenger did not lodge in a cabin is my assumption and might be incorrect.????

# %%
titanic['cabin'].value_counts().head(10).plot(kind='bar', color = 'blue',figsize=(18,5))

# %%
titanic['cabin'].value_counts().head(10)
# Out:
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# B96 B98            4
# F4                 4
# C22 C26            4
# C78                4
# D                  4
# F2                 4
# Name: cabin, dtype: int64

# %%
#embarked attribute
titanic['embarked'].describe()
# Out:
# count     1307
# unique       3
# top          S
# freq       914
# Name: embarked, dtype: object

# %%
#check missing values 
titanic[titanic.embarked.isnull()]
# Out:
#      pclass  survived                                       name     sex  \
# 168       1         1                        Icard, Miss. Amelie  female
# 284       1         1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       age  sibsp  parch  ticket  fare cabin embarked boat  body  \
# 168  38.0      0      0  113572  80.0   B28      NaN    6   NaN
# 284  62.0      0      0  113572  80.0   B28      NaN    6   NaN
#
#           home.dest age_category
# 168             NaN        adult
# 284  Cincinatti, OH        adult

# %%
titanic.embarked.value_counts().plot(kind='bar', color = 'blue',figsize=(9,5))

# %%
titanic.embarked.value_counts()/titanic.embarked.count()*100
# Out:
# S    69.931140
# C    20.657995
# Q     9.410865
# Name: embarked, dtype: float64

# %% [markdown]
# The result above shows that ~69% of the passengers embarked from "S".. and ~20% embarked from "C".. and ~9% embarked from "Q"

# %%
#boat attribute 
titanic['boat'].describe()
# Out:
# count     486
# unique     28
# top        13
# freq       39
# Name: boat, dtype: object

# %%
#checking missing data
titanic[titanic.boat.isnull()]
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                             Andrews, Mr. Thomas Jr
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 15         1         0                                Baumann, Mr. John D
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 25         1         0                                Birnbaum, Mr. Jakob
# 30         1         0                       Blackwell, Mr. Stephen Weart
# 34         1         0                           Borebank, Mr. John James
# 38         1         0                            Brady, Mr. John Bertram
# 39         1         0                                 Brandeis, Mr. Emil
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 45         1         0                  Butt, Major. Archibald Willingham
# 46         1         0                              Cairns, Mr. Alexander
# 51         1         0                           Carlsson, Mr. Frans Olof
# 52         1         0                            Carrau, Mr. Francisco M
# 53         1         0                             Carrau, Mr. Jose Pedro
# 58         1         0                             Case, Mr. Howard Brown
# 60         1         0                      Cavendish, Mr. Tyrell William
# 62         1         0                        Chaffee, Mr. Herbert Fuller
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 71         1         0                           Clark, Mr. Walter Miller
# 74         1         0                        Clifford, Mr. George Quincy
# 75         1         0                         Colley, Mr. Edward Pomeroy
# 77         1         0                   Compton, Mr. Alexander Taylor Jr
# 80         1         0                          Crafton, Mr. John Bertram
# 81         1         0                       Crosby, Capt. Edward Gifford
# 84         1         0                          Cumings, Mr. John Bradley
# ...      ...       ...                                                ...
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1278       3         0                             Vendel, Mr. Olof Edvin
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1280       3         0                                    Vovk, Mr. Janko
# 1281       3         0                               Waelens, Mr. Achille
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1285       3         0                                Wenzel, Mr. Linhart
# 1287       3         0                   Widegren, Mr. Carl/Charles Peter
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1289       3         0                            Wiklund, Mr. Karl Johan
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1294       3         0                               Williams, Mr. Leslie
# 1295       3         0                                Windelov, Mr. Einar
# 1296       3         0                                   Wirz, Mr. Albert
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1298       3         0                          Wittevrongel, Mr. Camille
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301       3         0                               Youseff, Mr. Gerious
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
# 1306       3         0                          Zakarian, Mr. Mapriededer
# 1307       3         0                                Zakarian, Mr. Ortin
# 1308       3         0                                 Zimmerman, Mr. Leo
#
#          s
# 1306    male  26.5      0      0              2656    7.2250          NaN
# 1307    male  27.0      0      0              2670    7.2250          NaN
# 1308    male  29.0      0      0            315082    7.8750          NaN
#
#      embarked boat   body                         home.dest
# 2           S  NaN    NaN   Montreal, PQ / Chesterville, ON
# 3           S  NaN  135.0   Montreal, PQ / Chesterville, ON
# 4           S  NaN    NaN   Montreal, PQ / Chesterville, ON
# 7           S  NaN    NaN                       Belfast, NI
# 9           C  NaN   22.0               Montevideo, Uruguay
# 10          C  NaN  124.0                      New York, NY
# 15          S  NaN    NaN                      New York, NY
# 16          C  NaN    NaN                      Montreal, PQ
# 25          C  NaN  148.0                 San Francisco, CA
# 30          S  NaN    NaN                       Trenton, NJ
# 34          S  NaN    NaN             London / Winnipeg, MB
# 38          S  NaN    NaN                       Pomeroy, WA
# 39          C  NaN  208.0                         Omaha, NE
# 40          C  NaN    NaN                  Philadelphia, PA
# 45          S  NaN    NaN                    Washington, DC
# 46          S  NaN    NaN                               NaN
# 51          S  NaN    NaN                      New York, NY
# 52          S  NaN    NaN               Montevideo, Uruguay
# 53          S  NaN    NaN               Montevideo, Uruguay
# 58          S  NaN    NaN  Ascot, Berkshire / Rochester, NY
# 60          S  NaN  172.0           Little Onn Hall, Staffs
# 62          S  NaN    NaN                        Amenia, ND
# 70          S  NaN    NaN      Liverpool, England / Belfast
# 71          C  NaN    NaN                   Los Angeles, CA
# 74          S  NaN    NaN                     Stoughton, MA
# 75          S  NaN    NaN                      Victoria, BC
# 77          C  NaN    NaN                      Lakewood, NJ
# 80          S  NaN    NaN                     Roachdale, IN
# 81          S  NaN  269.0                     Milwaukee, WI
# 84          C  NaN    NaN                      New York, NY
# ...       ...  ...    ...                               ...
# 1276        S  NaN    NaN                               NaN
# 1278        S  NaN    NaN                               NaN
# 1279        S  NaN    NaN                               NaN
# 1280        S  NaN    NaN                               NaN
# 1281        S  NaN    NaN    Antwerp, Belgium / Stanton, OH
# 1282        S  NaN    NaN                               NaN
# 1283        S  NaN    NaN                               NaN
# 1284        S  NaN    NaN                               NaN
# 1285        S  NaN  298.0                               NaN
# 1287        S  NaN    NaN                               NaN
# 1288        S  NaN  314.0                               NaN
# 1289        S  NaN    NaN                               NaN
# 1290        S  NaN    NaN                               NaN
# 1291        S  NaN    NaN                               NaN
# 1292        S  NaN    NaN                               NaN
# 1293        S  NaN    NaN                               NaN
# 1294        S  NaN   14.0                               NaN
# 1295        S  NaN    NaN                               NaN
# 1296        S  NaN  131.0                               NaN
# 1297        S  NaN    NaN                               NaN
# 1298        S  NaN    NaN                               NaN
# 1300        C  NaN    NaN                               NaN
# 1301        C  NaN  312.0                               NaN
# 1302        C  NaN    NaN                               NaN
# 1303        C  NaN    NaN                               NaN
# 1304        C  NaN  328.0                               NaN
# 1305        C  NaN    NaN                               NaN
# 1306        C  NaN  304.0                               NaN
# 1307        C  NaN    NaN                               NaN
# 1308        S  NaN    NaN                               NaN
#
# [823 rows x 14 columns]

# %% [markdown]
# we have 823 rows with missing boat values

# %%
titanic['boat'].value_counts().plot(kind='bar', color = 'blue',figsize=(18,5))

# %%
#top 5 most frequent boats
titanic.boat.value_counts().head(5)
# Out:
# 13    39
# C     38
# 15    37
# 14    33
# 4     31
# Name: boat, dtype: int64

# %%
#top 5 most frequent boats (persentage)
titanic.boat.value_counts().head(5)/titanic.boat.count()*100
# Out:
# 13    8.024691
# C     7.818930
# 15    7.613169
# 14    6.790123
# 4     6.378601
# Name: boat, dtype: float64

# %%
#body attribute 
titanic['body'].describe()
# Out:
# /Users/Ray/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    121.000000
# mean     160.809917
# std       97.696922
# min        1.000000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max      328.000000
# Name: body, dtype: float64

# %%
#checking missing data
titanic[titanic.body.isnull()]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 15         1         0                                Baumann, Mr. John D
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18         1         1                              Bazzani, Miss. Albina
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22         1         1                              Behr, Mr. Karl Howell
# 23         1         1                              Bidois, Miss. Rosalie
# 24         1         1                                  Bird, Miss. Ellen
# 26         1         1                            Bishop, Mr. Dickinson H
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28         1         1                             Bissette, Miss. Amelia
# 29         1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 30         1         0                       Blackwell, Mr. Stephen Weart
# 31         1         1                                   Blank, Mr. Henry
# 32         1         1                            Bonnell, Miss. Caroline
# 33         1         1                           Bonnell, Miss. Elizabeth
# ...      ...       ...                                                ...
# 1272       3         0                        Vander Cruyssen, Mr. Victor
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1274       3         0                          Vander Planke, Mr. Julius
# 1275       3         0                    Vander Planke, Mr. Leo Edmondus
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1277       3         1                               Vartanian, Mr. David
# 1278       3         0                             Vendel, Mr. Olof Edvin
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1280       3         0                                    Vovk, Mr. Janko
# 1281       3         0                               Waelens, Mr. Achille
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                   Widegren, Mr. Carl/Charles Peter
# 1289       3         0                            Wiklund, Mr. Karl Johan
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1295       3         0                                Windelov, Mr. Einar
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1298       3         0                          Wittevrongel, Mr. Camille
# 1299       3         0                                Yasbeck, Mr. Antoni
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
# 1307       3         0                                Zakarian, Mr. Ortin
# 1308       3         0                                 Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch            ticket      fare    cabin  \
# 0     female  29.0000      0      0             24160  211.3375       B5
# 1       male   0.9167      1      2            113781  151.5500  C22 C26
# 2     female   2.0000      1      2            113781  151.5500  C22 C26
# 4     female  25.0000      1      2            113781  151.5500  C22 C26
# 5       male  48.0000      0      0             19952   26.5500      E12
# 6     female  63.0000      1      0             13502   77.9583       D7
# 7       male  39.0000      0      0            112050    0.0000      A36
# 8     female  53.0000      2      0             11769   51.4792     C101
# 11    female  18.0000      1      0          PC 17757  227.5250  C62 C64
# 12    female  24.0000      0      0          PC 17477   69.3000      B35
# 13    female  26.0000      0      0             19877   78.8500      NaN
# 14      male  80.0000      0      0             27042   30.0000      A23
# 15      male  28.0000      0      0          PC 17318   25.9250      NaN
# 16      male  24.0000      0      1          PC 17558  247.5208  B58 B60
# 17    female  50.0000      0      1          PC 17558  247.5208  B58 B60
# 18    female  32.0000      0      0             11813   76.2917      D15
# 19      male  36.0000      0      0             13050   75.2417       C6
# 20      male  37.0000      1      1             11751   52.5542      D35
# 21    female  47.0000      1      1             11751   52.5542      D35
# 22      male  26.0000      0      0            111369   30.0000     C148
# 23    female  42.0000      0      0          PC 17757  227.5250      NaN
# 24    female  29.0000      0      0          PC 17483  221.7792      C97
# 26      male  25.0000      1      0             11967   91.0792      B49
# 27    female  19.0000      1      0             11967   91.0792      B49
# 28    female  35.0000      0      0          PC 17760  135.6333      C99
# 29      male  28.0000      0      0            110564   26.5500      C52
# 30      male  45.0000      0      0            113784   35.5000        T
# 31      male  40.0000      0      0            112277   31.0000      A31
# 32    female  30.0000      0      0             36928  164.8667       C7
# 33    female  58.0000      0      0            113783   26.5500     C103
# ...      ...      ...    ...    ...               ...       ...      ...
# 1272    male  47.0000      0      0            345765    9.0000      NaN
# 1273  female  18.0000      2      0            345764   18.0000      NaN
# 1274    male  31.0000      3      0            345763   18.0000      NaN
# 1275    male  16.0000      2      0            345764   18.0000      NaN
# 1276  female  31.0000      1      0            345763   18.0000      NaN
# 1277    male  22.0000      0      0              2658    7.2250      NaN
# 1278    male  20.0000      0      0            350416    7.8542      NaN
# 1279  female  14.0000      0      0            350406    7.8542      NaN
# 1280    male  22.0000      0      0            349252    7.8958      NaN
# 1281    male  22.0000      0      0            345767    9.0000      NaN
# 1282    male  28.0000      0      0            359309    8.0500      NaN
# 1283    male  28.0000      0      0        C.A. 49867    7.5500      NaN
# 1284    male  28.0000      0      0  SOTON/OQ 3101316    8.0500      NaN
# 1286  female  38.0000      0      0              2688    7.2292      NaN
# 1287    male  51.0000      0      0            347064    7.7500      NaN
# 1289    male  21.0000      1      0           3101266    6.4958      NaN
# 1290  female  47.0000      1      0            363272    7.0000      NaN
# 1291    male  28.0000      0      0              3410    8.7125      NaN
# 1292    male  28.0000      0      0     S.O./P.P. 751    7.5500      NaN
# 1293    male  28.0000      0      0          A/5 2466    8.0500      NaN
# 1295    male  21.0000      0      0  SOTON/OQ 3101317    7.2500      NaN
# 1297    male  28.0000      0      0        A/4. 34244    7.2500      NaN
# 1298    male  36.0000      0      0            345771    9.5000      NaN
# 1299    male  27.0000      1      0              2659   14.4542      NaN
# 1300  female  15.0000      1      0              2659   14.4542      NaN
# 1302    male  28.0000      0      0              2647    7.2250      NaN
# 1303    male  28.0000      0      0              2627   14.4583      NaN
# 1305  female  28.0000      1      0              2665   14.4542      NaN
# 1307    male  27.0000      0      0              2670    7.2250      NaN
# 1308    male  29.0000      0      0            315082    7.8750      NaN
#
#      embarked   boat  body                           home.dest
# 0           S      2   NaN                        St Louis, MO
# 1           S     11   NaN     Montreal, PQ / Chesterville, ON
# 2           S    NaN   NaN     Montreal, PQ / Chesterville, ON
# 4           S    NaN   NaN     Montreal, PQ / Chesterville, ON
# 5           S      3   NaN                        New York, NY
# 6           S     10   NaN                          Hudson, NY
# 7           S    NaN   NaN                         Belfast, NI
# 8           S      D   NaN                 Bayside, Queens, NY
# 11          C      4   NaN                        New York, NY
# 12          C      9   NaN                       Paris, France
# 13          S      6   NaN                                 NaN
# 14          S      B   NaN                       Hessle, Yorks
# 15          S    NaN   NaN                        New York, NY
# 16          C    NaN   NaN                        Montreal, PQ
# 17          C      6   NaN                        Montreal, PQ
# 18          C      8   NaN                                 NaN
# 19          C      A   NaN                        Winnipeg, MN
# 20          S      5   NaN                        New York, NY
# 21          S      5   NaN                        New York, NY
# 22          C      5   NaN                        New York, NY
# 23          C      4   NaN                                 NaN
# 24          S      8   NaN                                 NaN
# 26          C      7   NaN                        Dowagiac, MI
# 27          C      7   NaN                        Dowagiac, MI
# 28          S      8   NaN                                 NaN
# 29          S      D   NaN  Stockholm, Sweden / Washington, DC
# 30          S    NaN   NaN                         Trenton, NJ
# 31          C      7   NaN                      Glen Ridge, NJ
# 32          S      8   NaN                      Youngstown, OH
# 33          S      8   NaN   Birkdale, England Cleveland, Ohio
# ...       ...    ...   ...                                 ...
# 1272        S    NaN   NaN                                 NaN
# 1273        S    NaN   NaN                                 NaN
# 1274        S    NaN   NaN                                 NaN
# 1275        S    NaN   NaN                                 NaN
# 1276        S    NaN   NaN                                 NaN
# 1277        C  13 15   NaN                                 NaN
# 1278        S    NaN   NaN                                 NaN
# 1279        S    NaN   NaN                                 NaN
# 1280        S    NaN   NaN                                 NaN
# 1281        S    NaN   NaN      Antwerp, Belgium / Stanton, OH
# 1282        S    NaN   NaN                                 NaN
# 1283        S    NaN   NaN                                 NaN
# 1284        S    NaN   NaN                                 NaN
# 1286        C      C   NaN                                 NaN
# 1287        S    NaN   NaN                                 NaN
# 1289        S    NaN   NaN                                 NaN
# 1290        S    NaN   NaN                                 NaN
# 1291        S    NaN   NaN                                 NaN
# 1292        S    NaN   NaN                                 NaN
# 1293        S    NaN   NaN                                 NaN
# 1295        S    NaN   NaN                                 NaN
# 1297        S    NaN   NaN                                 NaN
# 1298        S    NaN   NaN                                 NaN
# 1299        C      C   NaN                                 NaN
# 1300        C    NaN   NaN                                 NaN
# 1302        C    NaN   NaN                                 NaN
# 1303        C    NaN   NaN                                 NaN
# 1305        C    NaN   NaN                                 NaN
# 1307        C    NaN   NaN                                 NaN
# 1308        S    NaN   NaN                                 NaN
#
# [1188 rows x 14 columns]

# %% [markdown]
# we have 1188 rows missing the body value

# %%
#ticket attribute 
titanic['ticket'].describe()
# Out:
# count         1309
# unique         939
# top       CA. 2343
# freq            11
# Name: ticket, dtype: object

# %%
#checking missing data
titanic[titanic.ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
#top 10 most frequent Ticket
titanic['ticket'].value_counts().head(10)
# Out:
# CA. 2343        11
# CA 2144          8
# 1601             8
# S.O.C. 14879     7
# PC 17608         7
# 347082           7
# 347077           7
# 3101295          7
# 113781           6
# 19950            6
# Name: ticket, dtype: int64

# %%
##2. Use the `groupby` method to calculate the proportion of passengers that survived by sex.

# %%
sex_grouped=titanic.groupby('sex')
sex_grouped.describe()
# Out:
# /Users/Ray/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                      age        body        fare       parch      pclass  \
# sex
# female count  466.000000    8.000000  466.000000  466.000000  466.000000
#        mean    28.572067  166.625000   46.198097    0.633047    2.154506
#        std     13.300806  138.110657   63.292599    1.049579    0.866181
#        min      0.166700    7.000000    6.750000    0.000000    1.000000
#        25%     21.000000         NaN   10.504175    0.000000    1.000000
#        50%     28.000000         NaN   23.000000    0.000000    2.000000
#        75%     35.000000         NaN   55.331275    1.000000    3.000000
#        max     76.000000  328.000000  512.329200    9.000000    3.000000
# male   count  843.000000  113.000000  843.000000  843.000000  843.000000
#        mean    30.017892  160.398230   26.123575    0.247924    2.372479
#        std     12.659913   95.035289   42.471194    0.708938    0.811908
#        min      0.333300    1.000000    0.000000    0.000000    1.000000
#        25%     24.000000         NaN    7.864600    0.000000    2.000000
#        50%     28.000000         NaN   11.500000    0.000000    3.000000
#        75%     35.000000         NaN   26.550000    0.000000    3.000000
#        max     80.000000  322.000000  512.329200    9.000000    3.000000
#
#                    sibsp    survived
# sex
# female count  466.000000  466.000000
#        mean     0.652361    0.727468
#        std      1.101009    0.445741
#        min      0.000000    0.000000
#        25%      0.000000    0.000000
#        50%      0.000000    1.000000
#        75%      1.000000    1.000000
#        max      8.000000    1.000000
# male   count  843.000000  843.000000
#        mean     0.413998    0.190985
#        std      0.997928    0.393310
#        min      0.000000    0.000000
#        25%      0.000000    0.000000
#        50%      0.000000    0.000000
#        75%      1.000000    0.000000
#        max      8.000000    1.000000

# %%
a =sex_grouped.survived.sum()
a
# Out:
# sex
# female    339
# male      161
# Name: survived, dtype: int64

# %%
#males proportion survived
df_male = titanic.survived[titanic.sex == 'male'].value_counts()
a.male/df_male.sum()*100
#a.male/(a.male+a.female)
# Out:
# 19.098457888493474

# %%
#female proportion survived
df_female = titanic.survived[titanic.sex == 'female'].value_counts()
a.female/df_female.sum()*100
#f.male/(a.male+a.female)
# Out:
# 72.746781115879827

# %%
b=titanic.sex.value_counts()

# %%
c=a/b

# %%
c.plot(kind = 'bar', color = 'blue', figsize=(9,5))

# %% [markdown]
# the above results show that 19.09% of males survived, and 72.74% of females survived and wecan clearly see that females had a very high servival rate in comparison with males.

# %%
##3. Calculate the same proportion, but by class and sex.

# %%
group = pd.crosstab([titanic.pclass, titanic.sex], titanic.survived)

# %%
group.plot(kind = 'bar', stacked = True, color = ['red', 'blue'],figsize=(15,5))

# %%
group
# Out:
# survived         0    1
# pclass sex
# 1      female    5  139
#        male    118   61
# 2      female   12   94
#        male    146   25
# 3      female  110  106
#        male    418   75

# %%
flatten_1=group.reset_index()

# %%
flatten_1['sum']=flatten_1[0]+flatten_1[1]

# %%
flatten_1['proportion_of_passengers_surviving']=flatten_1[1]/flatten_1['sum']*100

# %%
flatten_1
# Out:
# survived  pclass     sex    0    1  sum  proportion_of_passengers_surviving
# 0              1  female    5  139  144                           96.527778
# 1              1    male  118   61  179                           34.078212
# 2              2  female   12   94  106                           88.679245
# 3              2    male  146   25  171                           14.619883
# 4              3  female  110  106  216                           49.074074
# 5              3    male  418   75  493                           15.212982

# %% [markdown]
# From the results above, the proportion of passennger survived by class and sex is:
# - Class1
#   - Males   34.07%
#   - Females 96.52%
# - Class2
#   - Males   14.61%
#   - Females 88.67%
# - Class3
#   - Males   15.21%
#   - Females 49.07%

# %%
##4. Create age categories: children (under 14 years), adolescents (14-20), adult (21-64), and senior(65+), and calculate survival proportions by age category, class and sex.

# %%
titanic['age_category'] = ''
titanic['age_category'][titanic['age'] < 14] = 'children'
titanic['age_category'][(titanic['age'] >= 14) & (titanic['age'] <= 20)] = 'adolescents'
titanic['age_category'][(titanic['age'] > 20) & (titanic['age'] <= 64)] = 'adult'
titanic['age_category'][titanic['age'] > 64] = 'senior'

# %%
g =titanic.groupby('age_category').survived.sum()
g =titanic.groupby('age_category').survived.value_counts()
g.plot(kind='bar', color = 'blue',figsize=(18,5))

# %%
group_4 = pd.crosstab([titanic.pclass, titanic.sex, titanic.age_category ], titanic.survived)

# %%
group_4
# Out:
# survived                      0    1
# pclass sex    age_category
# 1      female adolescents     0   15
#               adult           4  123
#               children        1    0
#               senior          0    1
#        male   adolescents     4    1
#               adult         108   54
#               children        0    5
#               senior          6    1
# 2      female adolescents     1   12
#               adult          11   68
#               children        0   14
#        male   adolescents    15    2
#               adult         129   12
#               children        0   11
#               senior          2    0
# 3      female adolescents    16   19
#               adult          78   72
#               children       16   15
#        male   adolescents    56    8
#               adult         334   55
#               children       25   12
#               senior          3    0

# %%
group_4.plot(kind = 'bar', stacked = True, color = ['red', 'blue'],figsize=(15,5))

# %%
flatten=group_4.reset_index()

# %%
flatten['sum']=flatten[0]+flatten[1]

# %%
flatten['proportion_of_passengers_surviving']=flatten[1]/flatten['sum']*100

# %%
flatten
# Out:
# survived  pclass     sex age_category    0    1  sum  \
# 0              1  female  adolescents    0   15   15
# 1              1  female        adult    4  123  127
# 2              1  female     children    1    0    1
# 3              1  female       senior    0    1    1
# 4              1    male  adolescents    4    1    5
# 5              1    male        adult  108   54  162
# 6              1    male     children    0    5    5
# 7              1    male       senior    6    1    7
# 8              2  female  adolescents    1   12   13
# 9              2  female        adult   11   68   79
# 10             2  female     children    0   14   14
# 11             2    male  adolescents   15    2   17
# 12             2    male        adult  129   12  141
# 13             2    male     children    0   11   11
# 14             2    male       senior    2    0    2
# 15             3  female  adolescents   16   19   35
# 16             3  female        adult   78   72  150
# 17             3  female     children   16   15   31
# 18             3    male  adolescents   56    8   64
# 19             3    male        adult  334   55  389
# 20             3    male     children   25   12   37
# 21             3    male       senior    3    0    3
#
# survived  proportion_of_passengers_surviving
# 0                                 100.000000
# 1                                  96.850394
# 2                                   0.000000
# 3                                 100.000000
# 4                                  20.000000
# 5                                  33.333333
# 6                                 100.000000
# 7                                  14.285714
# 8                                  92.307692
# 9                                  86.075949
# 10                                100.000000
# 11                                 11.764706
# 12                                  8.510638
# 13                                100.000000
# 14                                  0.000000
# 15                                 54.285714
# 16                                 48.000000
# 17                                 48.387097
# 18                                 12.500000
# 19                                 14.138817
# 20                                 32.432432
# 21                                  0.000000

# %% [markdown]
# From the results above, the proportion of passennger survived by class, age group, and sex is:
# - Class1
#   - Males
#       - seniors 14.28%
#       - adults  33.33%
#       - adolescents 20%
#       - childrens 100%
#   - Females
#       - seniors  100%
#       - adults  96.85%
#       - adolescents 100%
#       - childrens 0%
# - Class2
#   - Males
#       - seniors  0%
#       - adults  8.51%
#       - adolescents  11.76%
#       - childrens   100%
#   - Females
#       - seniors none
#       - adults  86.07%
#       - adolescents 92.30%
#       - childrens 100%
# - Class3
#   - Males
#       - seniors 0%
#       - adults 14.13%
#       - adolescents 12.50%
#       - childrens 32.43%
#   - Females
#       - seniors none
#       - adults 48%
#       - adolescents 54.28%
#       - childrens 48.38%

# %%
500/1309
# Out:
# 0.3819709702062643

# %%
#Passenger 784 and 785 had missing values for the variable age. The two passengers were both males that boarded the lower passenger class (pclass=3). The median age for all male passengers in the lower passenger class was 24 years old, and assign it to the two passengers’ age values.
